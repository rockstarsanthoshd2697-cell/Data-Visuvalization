# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:/Users/Ibscai30.DGVC-MCA/Documents/Supermarket.csv")
df.head()
# Out:
#    Product  Quantity  Unit Price
# 0        1        10        2000
# 1        2        20        3000
# 2        3        15        4000
# 3        4        16        5000
# 4        5        25        6000

# %%
x=df["Product"]
y=df["Quantity"]


plt.plot(x,y)
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.title("Product vs Quantity")
# Out:
# Text(0.5, 1.0, 'Product vs Quantity')

# %%
plt.bar(x,z)
plt.title("Product vs Unit Price")
plt.xlabel("Product")
plt.ylabel("Unit Price")
# Out:
# Text(0, 0.5, 'Unit Price')

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.bar(x,z)
# Out:
# <BarContainer object of 5 artists>
